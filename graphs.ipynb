# %% [markdown]
# # CNN Model with 128x128 image size and 10 epocs

# %%
from train import *
# Out:
# The device used is: cpu
# .........................Training.............................
# 1/10..........train loss : 0.20696625437485078 | train accuarcy : 93.162
# ..................evaluation.....................
# 1/10..........test_loss : 0.05260541914238529 | Test_accuracy : 98.41
# 2/10..........train loss : 0.050951965876272584 | train accuarcy : 98.432
# ..................evaluation.....................
# 2/10..........test_loss : 0.031939632401677076 | Test_accuracy : 99.03999999999999
# 3/10..........train loss : 0.033707566056175746 | train accuarcy : 98.938
# ..................evaluation.....................
# 3/10..........test_loss : 0.03514235335816318 | Test_accuracy : 98.97
# 4/10..........train loss : 0.026744379185671893 | train accuarcy : 99.198
# ..................evaluation.....................
# 4/10..........test_loss : 0.03009023827057225 | Test_accuracy : 99.13
# 5/10..........train loss : 0.02123669142150195 | train accuarcy : 99.328
# ...

# %%
images, labels = next(iter(train_loader))
images.shape
# Out:
# torch.Size([64, 1, 128, 128])

# %%
graph1=draw_graph(model2,input_size=(64,1,128,128))
graph1.visual_graph
# Out:
# (dot.exe:20312): Pango-WARNING **: couldn't load font "Linux libertine Not-Rotated 10", falling back to "Sans Not-Rotated 10", expect ugly output.

# %%
plt.plot(train_loss_list,label="Train Loss",color="green",linewidth=3,marker='o')
plt.plot(test_loss_list,label="Test Loss",color="purple",linewidth=3,marker='*')
plt.xlabel("Number of Epochs")
plt.ylabel("Loss")
plt.title("Epochs Vs Loss")
plt.legend()
plt.show()

# %%
plt.plot(train_acc_list,label="Train Accuracy",color="red",linewidth=3,marker='o')
plt.plot(test_acc_list,label="Test Accuracy",color="yellow",linewidth=3,marker='*')
plt.xlabel("Number of Epochs")
plt.ylabel("Accuracy")
plt.title("Epochs Vs Accuracy")
plt.legend()
plt.show()

# %%
class_names = test_loader.dataset.classes

# %%
def imshow(img):
    img = img * 0.3081 + 0.1307
    plt.imshow(np.transpose(img.numpy(), (1,2,0)))

dataiter = iter(test_loader)
images, labels = next(dataiter)

images, labels = images.to(device), labels.to(device)
outputs = model2(images)
_, preds = torch.max(outputs, 1)

plt.figure(figsize=(12,6))
for i in range(20):
    plt.subplot(4,5,i+1)
    imshow(images[i].cpu())
    plt.title(f"Pred: {class_names[preds[i]]}")
    plt.axis('off')
plt.show()

# %% [markdown]
# # CNN Model with 28x28 image size and 10 epocs

# %%
from train_28x28 import *
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%
# The device used is: cpu
# .........................Training.............................
# 1/6..........train loss : 0.15538902226728304 | train accuarcy : 95.256
# ..................evaluation.....................
# 1/6..........test_loss : 0.05246795420861168 | Test_accuracy : 98.3
# 2/6..........train loss : 0.04725555474627251 | train accuarcy : 98.526
# ..................evaluation.....................
# 2/6..........test_loss : 0.051497777829029756 | Test_accuracy : 98.27
# 3/6..........train loss : 0.030708618236996253 | train accuarcy : 98.982
# ..................evaluation.....................
# 3/6..........test_loss : 0.03483271903497802 | Test_accuracy : 98.77
# 4/6..........train loss : 0.023553003951826173 | train accuarcy : 99.208
# ..................evaluation.....................
# 4/6..........test_loss : 0.03140527618252583 | Test_accuracy : 98.85000000000001
# ...

# %%
images, labels = next(iter(train_loader))
images.shape
# Out:
# torch.Size([64, 1, 28, 28])

# %%
graph=draw_graph(model_28x28,input_size=(64,1,28,28))
graph.visual_graph
# Out:
# (dot.exe:21484): Pango-WARNING **: couldn't load font "Linux libertine Not-Rotated 10", falling back to "Sans Not-Rotated 10", expect ugly output.

# %%
plt.plot(train_loss_list,label="Train Loss",color="green",linewidth=3,marker='o')
plt.plot(test_loss_list,label="Test Loss",color="purple",linewidth=3,marker='*')
plt.xlabel("Number of Epochs")
plt.ylabel("Loss")
plt.title("Epochs Vs Loss")
plt.legend()
plt.show()

# %%
plt.plot(train_acc_list,label="Train Accuracy",color="red",linewidth=3,marker='o')
plt.plot(test_acc_list,label="Test Accuracy",color="yellow",linewidth=3,marker='*')
plt.xlabel("Number of Epochs")
plt.ylabel("Accuracy")
plt.title("Epochs Vs Accuracy")
plt.legend()
plt.show()
